# %%
import pandas as pd
from sqlalchemy import create_engine
import time 
import requests
from datetime import datetime
from dotenv import load_dotenv
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from sqlalchemy import create_engine
#       3 import time
#
# ModuleNotFoundError: No module named 'pandas'

# %%
base_url = "https://api.binance.com/api/v3"

end_points = {
    "latest_prices": "/ticker/price",
    "order_book": "/depth",
    "recent_trades": "/trades",
    "klines": "/klines",
    "ticker_24hr": "/ticker/24hr"
}

# %%
## Fetching from binance API (Generic API caller)
def gen_binance_API(end_points, params=None):
    url = base_url + end_points
    response = requests.get(url, params=params)
    data = response.json()
    print(data)
    return data

result = gen_binance_API(end_points["latest_prices"], params = {"symbol": "BTCUSDT"})
# Out:
# {'symbol': 'BTCUSDT', 'price': '115491.40000000'}

# %%
## to get all the top 5 coins by 24hr % gain
def get_top_five_coins():
    data = gen_binance_API(end_points["ticker_24hr"])  
    sorted_data = sorted(data, key=lambda x: float(x['priceChangePercent']), reverse=True) #to sort data in descending order using reverse
    top_five = [item['symbol'] for item in sorted_data[:5]] #list comprehension to get a list of top 5 symbols
    return top_five
get_top_five_coins()
# Out:
# [{'symbol': 'ETHBTC', 'priceChange': '-0.00036000', 'priceChangePercent': '-0.914', 'weightedAvgPrice': '0.03917625', 'prevClosePrice': '0.03941000', 'lastPrice': '0.03904000', 'lastQty': '0.80280000', 'bidPrice': '0.03903000', 'bidQty': '25.07480000', 'askPrice': '0.03904000', 'askQty': '17.37330000', 'openPrice': '0.03940000', 'highPrice': '0.03951000', 'lowPrice': '0.03886000', 'volume': '10875.35780000', 'quoteVolume': '426.05575792', 'openTime': 1757933306653, 'closeTime': 1758019706653, 'firstId': 509676132, 'lastId': 509751773, 'count': 75642}, {'symbol': 'LTCBTC', 'priceChange': '0.00000600', 'priceChangePercent': '0.607', 'weightedAvgPrice': '0.00098468', 'prevClosePrice': '0.00098900', 'lastPrice': '0.00099400', 'lastQty': '0.13100000', 'bidPrice': '0.00099300', 'bidQty': '261.03400000', 'askPrice': '0.00099400', 'askQty': '177.49500000', 'openPrice': '0.00098800', 'highPrice': '0.00099700', 'lowPrice': '0.00097400', 'volume': '21243.09500000', 'quoteVolume': '20.91765653', 'openTime': 1757933311709, 'closeTime': 1758019711709, 'firstId': 105830886, 'lastId': 105835972, 'count': 5087}, {'symbol': 'BNBBTC', 'priceChange': '0.00002000', 'priceChangePercent': '0.250', 'weightedAvgPrice': '0.00800267', 'prevClosePrice': '0.00800600', 'lastPrice': '0.00802600', 'lastQty': '0.18500000', 'bidPrice': '0.00802500', 'bidQty': '0.25300000', 'askPrice': '0.00802600', 'askQty': '2.95700000', 'openPrice': '0.00800600', 'highPrice': '0.00805600', 'lowPrice': '0.00796000', 'volume': '7686.14100000', 'quoteVolume': '61.50965840', 'openTime': 1757933305309, 'closeTime': 1758019705309, 'firstId': 275291970, 'lastId': 275310187, 'count': 18218}, {'symbol': 'NEOBTC', 'priceChange': '-0.00000021', 'priceChangePercent': '-0.368', 'weightedAvgPrice': '0.00005670', 'prevClosePrice': '0.00005691', 'lastPrice': '0.00005690', 'lastQty': '6.62000000', 'bidPrice': '0.00005691', 'bidQty': '12.48000000', 'askPrice': '0.00005709', 'askQty': '12.48000000', 'openPrice': '0.00005711', 'highPrice': '0.00005720', 'lowPrice': '0.00005608', 'volume': '6045.85000000', 'quoteVolume': '0.34282574', 'openTime': 1757933303705, 'closeTime': 1758019703705, 'firstId': 47710035, 'lastId': 47710241, 'count': 207}, {'symbol': 'QTUMETH', 'priceChange': '0.00000700', 'priceChangePercent': '1.311', 'weightedAvgPrice': '0.00053425', 'prevClosePrice': '0.00053700', 'lastPrice': '0.00054100', 'lastQty': '38.90000000', 'bidPrice': '0.00053700', 'bidQty': '144.10000000', 'askPrice': '0.00053900', 'askQty': '41.20000000', 'openPrice': '0.00053400', 'highPrice': '0.00054100', 'lowPrice': '0.00053400', 'volume': '7012.30000000', 'quoteVolume': '3.74634480', 'openTime': 1757933296307, 'closeTime': 1758019696307, 'firstId': 5535657, 'lastId': 5535698, 'count': 42}, {'symbol': 'EOSETH', 'priceChange': '-0.00000100', 'priceChangePercent': '-0.325', 'weightedAvgPrice': '0.00029918', 'prevClosePrice': '0.00000000', 'lastPrice': '0.00030670', 'lastQty': '8.30000000', 'bidPrice': '0.00000000', 'bidQty': '0.00000000', 'askPrice': '0.00000000', 'askQty': '0.00000000', 'openPrice': '0.00030770', 'highPrice': '0.00032500', 'lowPrice': '0.00028160', 'volume': '391642.70000000', 'quoteVolume': '117.17343445', 'openTime': 1755517270103, 'closeTime': 1755603670103, 'firstId': 23920853, 'lastId': 23924852, 'count': 4000}, {'symbol': 'SNTETH', 'priceChange': '0.00000231', 'priceChangePercent': '15.725', 'weightedAvgPrice': '0.00001396', 'prevClosePrice': '0.00000000', 'lastPrice': '0.00001700', 'lastQty': '203.00000000', 'bidPrice': '0.00000000', 'bidQty': '0.00000000', 'askPrice': '0.00000000', 'askQty': '0.00000000', 'openPrice': '0.00001469', 'highPrice': '0.00004538', 'lowPrice': '0.00001094', 'volume': '11484111.00000000', 'quoteVolume': '160.35207145', 'openTime': 1755517270103, 'closeTime': 1755603670103, 'firstId': 4106153, 'lastId': 4110152, 'count': 4000}, {'symbol': 'BNTETH', 'priceChange': '-0.00001900', 'priceChangePercent': '-8.574', 'weightedAvgPrice': '0.00021795', 'prevClosePric ...
# ['HYPERFDUSD', 'ZKCTRY', 'ZKCFDUSD', 'ZKCUSDC', 'ZKCUSDT']

# %%
# calling all endpoints for each top_five
def all_data_for_symbols(symbols):
    all_data = {}

    for symbol in symbols:
        print(f"\n getting data for: {symbol}")
        symbol_data = {}

        #latest prices
        symbol_data["latest_prices"] = gen_binance_API(
            end_points=["latest_prices"],
            params = {"symbol": symbol}
        )

        #order book
        symbol_data["order_book"] = gen_binance_API(
            end_points=["order_book"],
            params={"symbol": symbol}
        )

        #recent trades
        symbol_data["recent_trades"] = gen_binance_API(
            end_points=["recent_trades"],
            params={"symbol": symbol, "limit": 100}
        )

        #klines
        symbol_data["klines"] = gen_binance_API(
            end_points=["klines"],
            params={"symbol": symbol,
                    "interval": "1d",
                    "startTime": None,
                    "endTime": None,
                    "limit": 100
                    }
        )

        # 24 hr ticker stats
        symbol_data["ticker_24hr"] = gen_binance_API(
            end_points["ticker_24hr"],
            params={"symbol": symbol}
        )

        # saving all data into our all_data dict
        all_data[symbol] = symbol_data
    
    return all_data

# %%
# Collect and convert into DataFrame
def build_dataframe(symbols):
    all_data = []
    
    for symbol in symbols:
        row = {"symbol": symbol}
        row["latest_prices"] = gen_binance_API(end_points["latest_prices"], {"symbol": symbol})
        row["order_book"] = gen_binance_API(end_points["order_book"], {"symbol": symbol, "limit": 5})
        row["recent_trades"] = gen_binance_API(end_points["recent_trades"], {"symbol": symbol, "limit": 5})
        row["klines"] = gen_binance_API(end_points["klines"], {"symbol": symbol, "interval": "1d", "limit": 1})
        row["ticker_24hr"] = gen_binance_API(end_points["ticker_24hr"], {"symbol": symbol})
        all_data.append(row)

    return pd.DataFrame(all_data)

# %%
# Calling the function
symbols = get_top_five_coins()
all_data = build_dataframe(symbols)
# Out:
# [{'symbol': 'ETHBTC', 'priceChange': '-0.00036000', 'priceChangePercent': '-0.914', 'weightedAvgPrice': '0.03917625', 'prevClosePrice': '0.03941000', 'lastPrice': '0.03904000', 'lastQty': '0.80280000', 'bidPrice': '0.03903000', 'bidQty': '25.07480000', 'askPrice': '0.03904000', 'askQty': '17.37330000', 'openPrice': '0.03940000', 'highPrice': '0.03951000', 'lowPrice': '0.03886000', 'volume': '10875.35780000', 'quoteVolume': '426.05575792', 'openTime': 1757933306653, 'closeTime': 1758019706653, 'firstId': 509676132, 'lastId': 509751773, 'count': 75642}, {'symbol': 'LTCBTC', 'priceChange': '0.00000600', 'priceChangePercent': '0.607', 'weightedAvgPrice': '0.00098468', 'prevClosePrice': '0.00098900', 'lastPrice': '0.00099400', 'lastQty': '0.13100000', 'bidPrice': '0.00099300', 'bidQty': '265.38800000', 'askPrice': '0.00099400', 'askQty': '177.49500000', 'openPrice': '0.00098800', 'highPrice': '0.00099700', 'lowPrice': '0.00097400', 'volume': '21243.09500000', 'quoteVolume': '20.91765653', 'openTime': 1757933316883, 'closeTime': 1758019716883, 'firstId': 105830886, 'lastId': 105835972, 'count': 5087}, {'symbol': 'BNBBTC', 'priceChange': '0.00002000', 'priceChangePercent': '0.250', 'weightedAvgPrice': '0.00800267', 'prevClosePrice': '0.00800600', 'lastPrice': '0.00802600', 'lastQty': '0.18500000', 'bidPrice': '0.00802500', 'bidQty': '0.25300000', 'askPrice': '0.00802600', 'askQty': '2.03100000', 'openPrice': '0.00800600', 'highPrice': '0.00805600', 'lowPrice': '0.00796000', 'volume': '7686.14100000', 'quoteVolume': '61.50965840', 'openTime': 1757933315603, 'closeTime': 1758019715603, 'firstId': 275291970, 'lastId': 275310187, 'count': 18218}, {'symbol': 'NEOBTC', 'priceChange': '-0.00000021', 'priceChangePercent': '-0.368', 'weightedAvgPrice': '0.00005670', 'prevClosePrice': '0.00005691', 'lastPrice': '0.00005690', 'lastQty': '6.62000000', 'bidPrice': '0.00005691', 'bidQty': '12.48000000', 'askPrice': '0.00005709', 'askQty': '12.48000000', 'openPrice': '0.00005711', 'highPrice': '0.00005720', 'lowPrice': '0.00005608', 'volume': '6045.85000000', 'quoteVolume': '0.34282574', 'openTime': 1757933303705, 'closeTime': 1758019703705, 'firstId': 47710035, 'lastId': 47710241, 'count': 207}, {'symbol': 'QTUMETH', 'priceChange': '0.00000700', 'priceChangePercent': '1.311', 'weightedAvgPrice': '0.00053425', 'prevClosePrice': '0.00053700', 'lastPrice': '0.00054100', 'lastQty': '38.90000000', 'bidPrice': '0.00053700', 'bidQty': '144.10000000', 'askPrice': '0.00053900', 'askQty': '41.20000000', 'openPrice': '0.00053400', 'highPrice': '0.00054100', 'lowPrice': '0.00053400', 'volume': '7012.30000000', 'quoteVolume': '3.74634480', 'openTime': 1757933296307, 'closeTime': 1758019696307, 'firstId': 5535657, 'lastId': 5535698, 'count': 42}, {'symbol': 'EOSETH', 'priceChange': '-0.00000100', 'priceChangePercent': '-0.325', 'weightedAvgPrice': '0.00029918', 'prevClosePrice': '0.00000000', 'lastPrice': '0.00030670', 'lastQty': '8.30000000', 'bidPrice': '0.00000000', 'bidQty': '0.00000000', 'askPrice': '0.00000000', 'askQty': '0.00000000', 'openPrice': '0.00030770', 'highPrice': '0.00032500', 'lowPrice': '0.00028160', 'volume': '391642.70000000', 'quoteVolume': '117.17343445', 'openTime': 1755517855929, 'closeTime': 1755604255929, 'firstId': 23920853, 'lastId': 23924852, 'count': 4000}, {'symbol': 'SNTETH', 'priceChange': '0.00000231', 'priceChangePercent': '15.725', 'weightedAvgPrice': '0.00001396', 'prevClosePrice': '0.00000000', 'lastPrice': '0.00001700', 'lastQty': '203.00000000', 'bidPrice': '0.00000000', 'bidQty': '0.00000000', 'askPrice': '0.00000000', 'askQty': '0.00000000', 'openPrice': '0.00001469', 'highPrice': '0.00004538', 'lowPrice': '0.00001094', 'volume': '11484111.00000000', 'quoteVolume': '160.35207145', 'openTime': 1755517855929, 'closeTime': 1755604255929, 'firstId': 4106153, 'lastId': 4110152, 'count': 4000}, {'symbol': 'BNTETH', 'priceChange': '-0.00001900', 'priceChangePercent': '-8.574', 'weightedAvgPrice': '0.00021795', 'prevClosePric ...
# {'symbol': 'HYPERFDUSD', 'price': '0.35350000'}
# {'lastUpdateId': 18083239, 'bids': [], 'asks': []}
# [{'id': 17992, 'price': '0.35420000', 'qty': '33.90000000', 'quoteQty': '12.00738000', 'time': 1755176220520, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 17993, 'price': '0.33980000', 'qty': '882.30000000', 'quoteQty': '299.80554000', 'time': 1755212136724, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 17994, 'price': '0.35350000', 'qty': '150.70000000', 'quoteQty': '53.27245000', 'time': 1755214980061, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 17995, 'price': '0.35350000', 'qty': '79.30000000', 'quoteQty': '28.03255000', 'time': 1755214980103, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 17996, 'price': '0.35350000', 'qty': '71.50000000', 'quoteQty': '25.27525000', 'time': 1755214982467, 'isBuyerMaker': False, 'isBestMatch': True}]
# [[1755216000000, '0.35350000', '0.35350000', '0.35350000', '0.35350000', '0.00000000', 1755226799999, '0.00000000', 0, '0.00000000', '0.00000000', '0']]
# {'symbol': 'HYPERFDUSD', 'priceChange': '0.25030000', 'priceChangePercent': '242.539', 'weightedAvgPrice': '0.39324203', 'prevClosePrice': '0.00000000', 'lastPrice': '0.35350000', 'lastQty': '301.50000000', 'bidPrice': '0.00000000', 'bidQty': '0.00000000', 'askPrice': '0.00000000', 'askQty': '0.00000000', 'openPrice': '0.10320000', 'highPrice': '0.76220000', 'lowPrice': '0.09940000', 'volume': '1748253.10000000', 'quoteVolume': '687486.60232000', 'openTime': 1755515970140, 'closeTime': 1755602370140, 'firstId': 13997, 'lastId': 17996, 'count': 4000}
# {'symbol': 'ZKCTRY', 'price': '32.94000000'}
# {'lastUpdateId': 4815558, 'bids': [['32.91000000', '1075.80000000'], ['32.89000000', '45.80000000'], ['32.88000000', '654.30000000'], ['32.87000000', '818.10000000'], ['32.86000000', '818.90000000']], 'asks': [['32.93000000', '817.40000000'], ['32.94000000', '793.30000000'], ['32.95000000', '818.50000000'], ['32.96000000', '1706.70000000'], ['32.97000000', '811.40000000']]}
# [{'id': 258731, 'price': '32.80000000', 'qty': '404.60000000', 'quoteQty': '13270.88000000', 'time': 1758019742366, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 258732, 'price': '32.80000000', 'qty': '59.30000000', 'quoteQty': '1945.04000000', 'time': 1758019742366, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 258733, 'price': '32.80000000', 'qty': '47.30000000', 'quoteQty': '1551.44000000', 'time': 1758019742366, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 258734, 'price': '32.80000000', 'qty': '52.00000000', 'quoteQty': '1705.60000000', 'time': 1758019742367, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 258735, 'price': '32.83000000', 'qty': '100.00000000', 'quoteQty': '3283.00000000', 'time': 1758019742784, 'isBuyerMaker': True, 'isBestMatch': True}]
# [[1757980800000, '38.83000000', '39.37000000', '32.35000000', '32.89000000', '8598177.50000000', 1758067199999, '310935955.63900000', 44116, '4010344.90000000', '145395823.20000000', '0']]
# {'symbol': 'ZKCTRY', 'priceChange': '20.92000000', 'priceChangePercent': '175.209', 'weightedAvgPrice': '42.72770011', 'prevClosePrice': '0.00000000', 'lastPrice': '32.86000000', 'lastQty': '136.30000000', 'bidPrice': '32.86000000', 'bidQty': '3595.90000000', 'askPrice': '32.88000000', 'askQty': '281.30000000', 'openPrice': '11.94000000', 'highPrice': '121.54000000', 'lowPrice': '11.94000000', 'volume': '38778701.20000000', 'quoteVolume': '1656924715.64100000', 'openTime': 1757933350255, 'closeTime': 1758019750255, 'firstId': 0, 'lastId': 258757, 'count': 258758}
# {'symbol': 'ZKCFDUSD', 'price': '0.79600000'}
# {'lastUpdateId': 1381365, 'bids': [['0.79460000', '135.30000000'], ['0.79360000', '7.00000000'], ['0.79310000', '1910.30000000'], ['0.79300000', '1027.90000000'], ['0.79200000', '7.00000000']], 'asks': [['0.79590000', '12.60000000'], ['0.79850000', '135.30000000'], ['0.80040000', '81.50000000'], ['0.80050000', '125.40000000'], ['0.80060000', '81.50000000']]}
# [{'id': 5215, 'price': '0.79680000', 'qty': '7.00000000', 'quoteQty': '5.57760000', 'time': 1758019568601, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 5216, 'price': '0.80010000', 'qty': '142.30000000', 'quoteQty': '113.85423000', 'time': 1758019711693, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 5217, 'price': '0.79840000', 'qty': '6.90000000', 'quoteQty': '5.50896000', 'time': 1758019731862, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 5218, 'price': '0.79680000', 'qty': '7.00000000', 'quoteQty': '5.57760000', 'time': 1758019742265, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 5219, 'price': '0.79600000', 'qty': '7.00000000', 'quoteQty': '5.57200000', 'time': 1758019742265, 'isBuyerMaker': True, 'isBestMatch': True}]
# [[1757980800000, '0.94000000', '0.95190000', '0.78820000', '0.79600000', '137927.60000000', 1758067199999, '118777.83770000', 1987, '51544.60000000', '44894.18212000', '0']]
# {'symbol': 'ZKCFDUSD', 'priceChange': '0.50590000', 'priceChangePercent': '174.388', 'weightedAvgPrice': '1.07513312', 'prevClosePrice': '0.00000000', 'lastPrice': '0.79600000', 'lastQty': '7.00000000', 'bidPrice': '0.79660000', 'bidQty': '284.60000000', 'askPrice': '0.79820000', 'askQty': '50.90000000', 'openPrice': '0.29010000', 'highPrice': '1.77700000', 'lowPrice': '0.29010000', 'volume': '715191.80000000', 'quoteVolume': '768926.39403000', 'openTime': 1757933369230, 'closeTime': 1758019769230, 'firstId': 0, 'lastId': 5219, 'count': 5220}
# {'symbol': 'ZKCUSDT', 'price': '0.79470000'}
# {'lastUpdateId': 24062792, 'bids': [['0.79410000', '481.30000000'], ['0.79400000', '300.40000000'], ['0.79390000', '175.00000000'], ['0.79380000', '352.50000000'], ['0.79370000', '368.10000000']], 'asks': [['0.79430000', '1764.90000000'], ['0.79460000', '950.80000000'], ['0.79470000', '850.00000000'], ['0.79480000', '192.80000000'], ['0.79490000', '40.70000000']]}
# [{'id': 1953773, 'price': '0.79500000', 'qty': '15.10000000', 'quoteQty': '12.00450000', 'time': 1758019777881, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 1953774, 'price': '0.79490000', 'qty': '253.60000000', 'quoteQty': '201.58664000', 'time': 1758019778392, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 1953775, 'price': '0.79490000', 'qty': '30.30000000', 'quoteQty': '24.08547000', 'time': 1758019778392, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 1953776, 'price': '0.79470000', 'qty': '85.90000000', 'quoteQty': '68.26473000', 'time': 1758019778392, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 1953777, 'price': '0.79480000', 'qty': '253.60000000', 'quoteQty': '201.56128000', 'time': 1758019778396, 'isBuyerMaker': True, 'isBestMatch': True}]
# [[1757980800000, '0.93910000', '0.95280000', '0.78210000', '0.79480000', '64229946.40000000', 1758067199999, '56700676.21321000', 339640, '34350025.40000000', '30346774.50062000', '0']]
# {'symbol': 'ZKCUSDT', 'priceChange': '0.50620000', 'priceChangePercent': '174.552', 'weightedAvgPrice': '1.08109266', 'prevClosePrice': '0.00000000', 'lastPrice': '0.79620000', 'lastQty': '61.00000000', 'bidPrice': '0.79630000', 'bidQty': '507.30000000', 'askPrice': '0.79650000', 'askQty': '158.50000000', 'openPrice': '0.29000000', 'highPrice': '1.88400000', 'lowPrice': '0.29000000', 'volume': '298104012.20000000', 'quoteVolume': '322278059.78380000', 'openTime': 1757933385282, 'closeTime': 1758019785282, 'firstId': 0, 'lastId': 1953850, 'count': 1953851}
# {'symbol': 'ZKCUSDC', 'price': '0.79780000'}
# {'lastUpdateId': 4793998, 'bids': [['0.79570000', '165.70000000'], ['0.79550000', '634.00000000'], ['0.79540000', '904.80000000'], ['0.79510000', '634.00000000'], ['0.79500000', '634.00000000']], 'asks': [['0.79640000', '634.00000000'], ['0.79660000', '104.00000000'], ['0.79670000', '634.00000000'], ['0.79680000', '242.40000000'], ['0.79690000', '634.00000000']]}
# [{'id': 134312, 'price': '0.79660000', 'qty': '588.60000000', 'quoteQty': '468.87876000', 'time': 1758019786008, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 134313, 'price': '0.79760000', 'qty': '6.90000000', 'quoteQty': '5.50344000', 'time': 1758019787431, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 134314, 'price': '0.79780000', 'qty': '5.60000000', 'quoteQty': '4.46768000', 'time': 1758019787431, 'isBuyerMaker': False, 'isBestMatch': True}, {'id': 134315, 'price': '0.79570000', 'qty': '76.80000000', 'quoteQty': '61.10976000', 'time': 1758019790701, 'isBuyerMaker': True, 'isBestMatch': True}, {'id': 134316, 'price': '0.79590000', 'qty': '125.80000000', 'quoteQty': '100.12422000', 'time': 1758019791141, 'isBuyerMaker': True, 'isBestMatch': True}]
# [[1757980800000, '0.93960000', '0.95300000', '0.78240000', '0.79510000', '4754854.40000000', 1758067199999, '4166761.77566000', 27726, '2150688.00000000', '1887957.11578000', '0']]
# {'symbol': 'ZKCUSDC', 'priceChange': '0.50580000', 'priceChangePercent': '174.354', 'weightedAvgPrice': '1.06307994', 'prevClosePrice': '0.00000000', 'lastPrice': '0.79590000', 'lastQty': '731.10000000', 'bidPrice': '0.79530000', 'bidQty': '580.00000000', 'askPrice': '0.79610000', 'askQty': '634.00000000', 'openPrice': '0.29010000', 'highPrice': '2.50000000', 'lowPrice': '0.29010000', 'volume': '20398838.30000000', 'quoteVolume': '21685595.74770000', 'openTime': 1757933404264, 'closeTime': 1758019804264, 'firstId': 0, 'lastId': 134332, 'count': 134333}

# %%
# Nested Data preview
print(all_data.head())
# Out:
#        symbol                                    latest_prices  \
# 0  HYPERFDUSD  {'symbol': 'HYPERFDUSD', 'price': '0.35350000'}
# 1      ZKCTRY     {'symbol': 'ZKCTRY', 'price': '32.94000000'}
# 2    ZKCFDUSD    {'symbol': 'ZKCFDUSD', 'price': '0.79600000'}
# 3     ZKCUSDT     {'symbol': 'ZKCUSDT', 'price': '0.79470000'}
# 4     ZKCUSDC     {'symbol': 'ZKCUSDC', 'price': '0.79780000'}
#
#                                           order_book  \
# 0  {'lastUpdateId': 18083239, 'bids': [], 'asks':...
# 1  {'lastUpdateId': 4815558, 'bids': [['32.910000...
# 2  {'lastUpdateId': 1381365, 'bids': [['0.7946000...
# 3  {'lastUpdateId': 24062792, 'bids': [['0.794100...
# 4  {'lastUpdateId': 4793998, 'bids': [['0.7957000...
#
#                                        recent_trades  \
# 0  [{'id': 17992, 'price': '0.35420000', 'qty': '...
# 1  [{'id': 258731, 'price': '32.80000000', 'qty':...
# 2  [{'id': 5215, 'price': '0.79680000', 'qty': '7...
# 3  [{'id': 1953773, 'price': '0.79500000', 'qty':...
# 4  [{'id': 134312, 'price': '0.79660000', 'qty': ...
#
#                                               klines  \
# 0  [[1755216000000, 0.35350000, 0.35350000, 0.353...
# 1  [[1757980800000, 38.83000000, 39.37000000, 32....
# 2  [[1757980800000, 0.94000000, 0.95190000, 0.788...
# 3  [[1757980800000, 0.93910000, 0.95280000, 0.782...
# 4  [[1757980800000, 0.93960000, 0.95300000, 0.782...
#
#                                          ticker_24hr
# 0  {'symbol': 'HYPERFDUSD', 'priceChange': '0.250...
# 1  {'symbol': 'ZKCTRY', 'priceChange': '20.920000...
# 2  {'symbol': 'ZKCFDUSD', 'priceChange': '0.50590...
# 3  {'symbol': 'ZKCUSDT', 'priceChange': '0.506200...
# 4  {'symbol': 'ZKCUSDC', 'priceChange': '0.505800...

# %%
#Flattening all_data from being nested
def flatten_all_data(all_data):
    flat_rows = []

    for _, row in all_data.iterrows():
        flat_row = {"symbol": row["symbol"]}

        # Latest price → simple dict
        if isinstance(row["latest_prices"], dict):
            flat_row["price"] = row["latest_prices"].get("price")

        # Order book → nested dict (we'll just take best bid/ask)
        if isinstance(row["order_book"], dict):
            bids = row["order_book"].get("bids", [])
            asks = row["order_book"].get("asks", [])
            if bids:  
                flat_row["best_bid_price"] = bids[0][0]
                flat_row["best_bid_qty"] = bids[0][1]
            if asks:
                flat_row["best_ask_price"] = asks[0][0]
                flat_row["best_ask_qty"] = asks[0][1]

        # Recent trades → list of dicts (take first trade)
        if isinstance(row["recent_trades"], list) and len(row["recent_trades"]) > 0:
            first_trade = row["recent_trades"][0]
            flat_row["trade_id"] = first_trade.get("id")
            flat_row["trade_price"] = first_trade.get("price")
            flat_row["trade_qty"] = first_trade.get("qty")

        # Klines → list of lists (OHLCV data)
        if isinstance(row["klines"], list) and len(row["klines"]) > 0:
            kline = row["klines"][0]
            flat_row["open"] = kline[1]
            flat_row["high"] = kline[2]
            flat_row["low"] = kline[3]
            flat_row["close"] = kline[4]
            flat_row["volume"] = kline[5]

        # Ticker stats → dict
        if isinstance(row["ticker_24hr"], dict):
            flat_row["priceChangePercent"] = row["ticker_24hr"].get("priceChangePercent")
            flat_row["volume_24h"] = row["ticker_24hr"].get("volume")
            flat_row["quoteVolume_24h"] = row["ticker_24hr"].get("quoteVolume")

        flat_rows.append(flat_row)

    return pd.DataFrame(flat_rows)

# %%
# Flat data preview
flat_df = flatten_all_data(all_data)
print(flat_df)
# Out:
#        symbol        price  trade_id  trade_price     trade_qty         open  \
# 0  HYPERFDUSD   0.35350000     17992   0.35420000   33.90000000   0.35350000
# 1      ZKCTRY  32.94000000    258731  32.80000000  404.60000000  38.83000000
# 2    ZKCFDUSD   0.79600000      5215   0.79680000    7.00000000   0.94000000
# 3     ZKCUSDT   0.79470000   1953773   0.79500000   15.10000000   0.93910000
# 4     ZKCUSDC   0.79780000    134312   0.79660000  588.60000000   0.93960000
#
#           high          low        close             volume  \
# 0   0.35350000   0.35350000   0.35350000         0.00000000
# 1  39.37000000  32.35000000  32.89000000   8598177.50000000
# 2   0.95190000   0.78820000   0.79600000    137927.60000000
# 3   0.95280000   0.78210000   0.79480000  64229946.40000000
# 4   0.95300000   0.78240000   0.79510000   4754854.40000000
#
#   priceChangePercent          volume_24h      quoteVolume_24h best_bid_price  \
# 0            242.539    1748253.10000000      687486.60232000            NaN
# 1            175.209   38778701.20000000  1656924715.64100000    32.91000000
# 2            174.388     715191.80000000      768926.39403000     0.79460000
# 3            174.552  298104012.20000000   322278059.78380000     0.79410000
# 4            174.354   20398838.30000000    21685595.74770000     0.79570000
#
#     best_bid_qty best_ask_price   best_ask_qty
# 0            NaN            NaN            NaN
# 1  1075.80000000    32.93000000   817.40000000
# 2   135.30000000     0.79590000    12.60000000
# 3   481.30000000     0.79430000  1764.90000000
# 4   165.70000000     0.79640000   634.00000000

# %%
## Loading the data to postgres
db_user = os.getenv("db_user")
db_password = os.getenv("db_password")
db_host = os.getenv("db_host")
db_port = os.getenv("db_port")
db_name = os.getenv("db_name")

engine = create_engine('postgresql://avnadmin:AVNS_JketIJpAtyoXVBHM2bW@pg-c8ca02a-calebkilemba843-b74b.l.aivencloud.com:10721/defaultdb')

# %%
engine = create_engine("postgresql://caleb:%23Jesus2025@localhost:5432/caleb")

# %%
flat_df.to_sql("binance_data", engine, schema="public", if_exists="replace", index=False)
# Out:
# 5
